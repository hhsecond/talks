# %%
from hangar import Repository

import numpy as np
import pickle
import gzip
import matplotlib.pyplot as plt

from tqdm.auto import tqdm

# %% [markdown]
# - Time travel through the historical evolution of a dataset
# - Zero-cost Branching to enable exploratory analysis and collaboration
# - Cheap Merging to build datasets over time (with multiple collaborators)
# - Completely abstracted organization and management of data files on disk
# - Ability to only retrieve a small portion of the data (as needed) while still maintaining complete historical record
# - Ability to push and pull changes directly to collaborators or a central server (ie a truly distributed version control system)

# %% [markdown]
# ## Part 1: Branching & Merging

# %%
repo = Repository(path='/Users/rick/projects/tensorwerk/hangar/dev/mnist/')
# Out:
# HANGAR RUNTIME WARNING: no repository exists at /Users/rick/projects/tensorwerk/hangar/dev/mnist/__hangar, please use `init_repo` function

# %%
repo.init(user_name='Rick Izzo', user_email='rick@tensorwerk.com', remove_old=True)
# Out:
# Hangar Repo initialized at: /Users/rick/projects/tensorwerk/hangar/dev/mnist/__hangar
# '/Users/rick/projects/tensorwerk/hangar/dev/mnist/__hangar'

# %%
# Load the dataset
with gzip.open('/Users/rick/projects/tensorwerk/hangar/dev/data/mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='bytes')

def rescale(array):
    array = array * 256
    rounded = np.round(array)
    return rounded.astype(np.uint8())

sample_trimg = rescale(train_set[0][0])
sample_trlabel = np.array([train_set[1][0]])
trimgs = rescale(train_set[0])
trlabels = train_set[1]

sample_vimg = rescale(valid_set[0][0])
sample_vlabel = np.array([valid_set[1][0]])
vimgs = rescale(valid_set[0])
vlabels = valid_set[1]

sample_teimg = rescale(test_set[0][0])
sample_telabel = np.array([test_set[1][0]])
teimgs = rescale(test_set[0])
telabels = test_set[1]

# %%
co = repo.checkout(write=True)

dset_trimgs = co.datasets.init_dataset(name='train_images', prototype=sample_trimg)
dset_trlabels = co.datasets.init_dataset(name='train_labels', prototype=sample_trlabel)

pbar = tqdm(total=trimgs.shape[0])
with dset_trimgs, dset_trlabels:
    for idx, img in enumerate(trimgs):
        if (idx % 500 == 0):
            pbar.update(500)
        name = str(idx)
        dset_trimgs[name] = img
        dset_trlabels[name] = np.array([trlabels[idx]])
pbar.close()

co.metadata['hello'] = 'world'

co.commit('first commit adding training images and labels')

repo.log()

repo.create_branch('add-validation')
repo.create_branch('add-test')
repo.create_branch('untouched-live-demo-branch')

co.close()

co = repo.checkout(write=True, branch_name='add-validation')

dset_vimgs = co.datasets.init_dataset(name='validation_images', prototype=sample_vimg)
dset_vlabels = co.datasets.init_dataset(name='validation_labels', prototype=sample_vlabel)

pbar = tqdm(total=vimgs.shape[0])
with dset_vimgs, dset_vlabels:
    for idx, img in enumerate(vimgs):
        if (idx % 500 == 0):
            pbar.update(500)
        name = str(idx)
        dset_vimgs[name] = img
        dset_vlabels[name] = np.array([vlabels[idx]])
pbar.close()

co.commit('commit adding validation images and labels')

co.close()

co = repo.checkout(write=True, branch_name='add-test')

dset_teimgs = co.datasets.init_dataset(name='test_images', prototype=sample_teimg)

pbar = tqdm(total=teimgs.shape[0])
with dset_teimgs:
    for idx, img in enumerate(teimgs):
        if (idx % 500 == 0):
            pbar.update(500)
        name = str(idx)
        dset_teimgs[name] = img
pbar.close()

co.commit('added testing images only')

dset_telabels = co.datasets.init_dataset(name='test_labels', prototype=sample_telabel)

pbar = tqdm(total=telabels.shape[0])
with dset_telabels:
    for idx, lab in enumerate(telabels):
        if (idx % 500 == 0):
            pbar.update(500)
        name = str(idx)
        dset_telabels[name] = np.array([lab])
pbar.close()

co.commit('added testing labels only')
co.close()
# Out:
# Dataset Specification:: Name: `train_images`, Initialization style: `prototype`, Shape: `(784,)`, DType: `uint8`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(784,)`
# Dataset Initialized: `train_images`
# Dataset Specification:: Name: `train_labels`, Initialization style: `prototype`, Shape: `(1,)`, DType: `int64`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(1,)`
# Dataset Initialized: `train_labels`
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# Commit operation requested with message: first commit adding training images and labels
# (6478291, 1570791, 65536)
# removing all stage hash records
# Commit completed. Commit hash: cd5593d4a87953cfc928597334a1b664c45557f4
# * cd5593d4a87953cfc928597334a1b664c45557f4 (master) : first commit adding training images and labels
# writer checkout of master closed
# Dataset Specification:: Name: `validation_images`, Initialization style: `prototype`, Shape: `(784,)`, DType: `uint8`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(784,)`
# Dataset Initialized: `validation_images`
# Dataset Specification:: Name: `validation_labels`, Initialization style: `prototype`, Shape: `(1,)`, DType: `int64`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(1,)`
# Dataset Initialized: `validation_labels`
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Commit operation requested with message: commit adding validation images and labels
# (7856529, 1888176, 65536)
# removing all stage hash records
# Commit completed. Commit hash: c2e49c3ef8eff20173f689af803c5d623d72c4fc
# writer checkout of add-validation closed
# Dataset Specification:: Name: `test_images`, Initialization style: `prototype`, Shape: `(784,)`, DType: `uint8`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(784,)`
# Dataset Initialized: `test_images`
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Commit operation requested with message: added testing images only
# (7107399, 1848732, 65536)
# removing all stage hash records
# Commit completed. Commit hash: 7b7f24e64689bda604ae48280cae3877c334dfe1
# Dataset Specification:: Name: `test_labels`, Initialization style: `prototype`, Shape: `(1,)`, DType: `int64`, Samples Named: `True`, Variable Shape: `False`, Max Shape: `(1,)`
# Dataset Initialized: `test_labels`
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Commit operation requested with message: added testing labels only
# (7736505, 1884188, 65536)
# removing all stage hash records
# Commit completed. Commit hash: 3115bf8611987cc5e661e55bf994423b60683f9c
# writer checkout of add-test closed

# %%
repo.list_branch_names()
# Out:
# ['add-test', 'add-validation', 'master', 'untouched-live-demo-branch']

# %%
repo.log(branch_name='add-test')
# Out:
# * 3115bf8611987cc5e661e55bf994423b60683f9c (add-test) : added testing labels only
# * 7b7f24e64689bda604ae48280cae3877c334dfe1 : added testing images only
# * cd5593d4a87953cfc928597334a1b664c45557f4 (master) (untouched-live-demo-branch) : first commit adding training images and labels

# %%
repo.log(branch_name='add-validation')
# Out:
# * c2e49c3ef8eff20173f689af803c5d623d72c4fc (add-validation) : commit adding validation images and labels
# * cd5593d4a87953cfc928597334a1b664c45557f4 (master) (untouched-live-demo-branch) : first commit adding training images and labels

# %%
co = repo.checkout(write=True, branch_name='master')

# %%
repo.log()
# Out:
# * cd5593d4a87953cfc928597334a1b664c45557f4 (master) (untouched-live-demo-branch) : first commit adding training images and labels

# %%
co.merge('merging the changes to the training datasets with the new additions of the validation datasets', dev_branch='add-validation')
# Out:
# Selected Fast-Forward Merge Stratagy
# removing all stage hash records
# 'c2e49c3ef8eff20173f689af803c5d623d72c4fc'

# %%
repo.log('master')
# Out:
# * c2e49c3ef8eff20173f689af803c5d623d72c4fc (add-validation) (master) : commit adding validation images and labels
# * cd5593d4a87953cfc928597334a1b664c45557f4 (untouched-live-demo-branch) : first commit adding training images and labels

# %%
repo.log('add-test')
# Out:
# * 3115bf8611987cc5e661e55bf994423b60683f9c (add-test) : added testing labels only
# * 7b7f24e64689bda604ae48280cae3877c334dfe1 : added testing images only
# * cd5593d4a87953cfc928597334a1b664c45557f4 (untouched-live-demo-branch) : first commit adding training images and labels

# %%
co.merge('adding in the new testing datasets', dev_branch='add-test')
# Out:
# Selected 3-Way Merge Strategy
# (9114743, 2201473, 65536)
# removing all stage hash records
# '3fd5d1fc99f08d901700c0c852a1575d7fc24df7'

# %%
co.close()
# Out:
# writer checkout of master closed

# %%
repo.log()
# Out:
# *   3fd5d1fc99f08d901700c0c852a1575d7fc24df7 (master) : adding in the new testing datasets
# |\
# | * 3115bf8611987cc5e661e55bf994423b60683f9c (add-test) : added testing labels only
# | * 7b7f24e64689bda604ae48280cae3877c334dfe1 : added testing images only
# * | c2e49c3ef8eff20173f689af803c5d623d72c4fc (add-validation) : commit adding validation images and labels
# |/
# * cd5593d4a87953cfc928597334a1b664c45557f4 (untouched-live-demo-branch) : first commit adding training images and labels

# %%
co = repo.checkout(write=True, branch_name='untouched-live-demo-branch')

# %%
repo.log()
# Out:
# * cd5593d4a87953cfc928597334a1b664c45557f4 (untouched-live-demo-branch) : first commit adding training images and labels

# %%
del co.datasets['train_images']['0']
del co.datasets['train_labels']['0']
co.commit('removed index zero for train images and labels')
# Out:
# Commit operation requested with message: removed index zero for train images and labels
# (6478169, 1570792, 65536)
# removing all stage hash records
# Commit completed. Commit hash: 395d988b638255ed75bd47e1d416fa75521e398e
# '395d988b638255ed75bd47e1d416fa75521e398e'

# %%
co.close()
# Out:
# writer checkout of untouched-live-demo-branch closed

# %%
co = repo.checkout(write=True, branch_name='master')

# %%
co.merge('merge of removals with master', 'untouched-live-demo-branch')
# Out:
# Selected 3-Way Merge Strategy
# (9114621, 2201461, 65536)
# removing all stage hash records
# '31d74893fb42562f26cdb23e818b436426589623'

# %%
repo.log()
# Out:
# *   31d74893fb42562f26cdb23e818b436426589623 (master) : merge of removals with master
# |\
# | * 395d988b638255ed75bd47e1d416fa75521e398e (untouched-live-demo-branch) : removed index zero for train images and labels
# * |   3fd5d1fc99f08d901700c0c852a1575d7fc24df7 : adding in the new testing datasets
# |\ \
# | * | 3115bf8611987cc5e661e55bf994423b60683f9c (add-test) : added testing labels only
# | * | 7b7f24e64689bda604ae48280cae3877c334dfe1 : added testing images only
# | |/
# * | c2e49c3ef8eff20173f689af803c5d623d72c4fc (add-validation) : commit adding validation images and labels
# |/
# * cd5593d4a87953cfc928597334a1b664c45557f4 : first commit adding training images and labels

# %%
co.datasets['train_images']
# Out:
#  Hangar DatasetDataWriter
#     Dataset Name     : train_images
#     Schema UUID      : bf3e41927db611e98cc88c859047adef
#     Schema Hash      : 976ba57033bb
#     Variable Shape   : False
#     (max) Shape      : (784,)
#     Datatype         : <class 'numpy.uint8'>
#     Named Samples    : True
#     Access Mode      : a
#     Num Samples      : 49999

# %%
co.metadata['foo'] = 'bar'
co.commit('test for conflicts')
# Out:
# Commit operation requested with message: test for conflicts
# (9114671, 2201495, 65536)
# removing all stage hash records
# Commit completed. Commit hash: 5131376482d70f40c3d1519b09b9cb74fde01379
# '5131376482d70f40c3d1519b09b9cb74fde01379'

# %%
co.close()
# Out:
# writer checkout of master closed

# %%
repo.create_branch('conflictbranch', base_commit='3115bf8611987cc5e661e55bf994423b60683f9c')
# Out:
# 'conflictbranch'

# %%
co = repo.checkout(write=True, branch_name='conflictbranch')

# %%
co.metadata['foo'] = 'world bar baz'

# %%
co.commit('hey there this should be a conflict')
# Out:
# Commit operation requested with message: hey there this should be a conflict
# (7736555, 1884220, 65536)
# removing all stage hash records
# Commit completed. Commit hash: ec8691ca9b18cf8a730cbeb9a34157983c45e162
# 'ec8691ca9b18cf8a730cbeb9a34157983c45e162'

# %%
co.close()
# Out:
# writer checkout of conflictbranch closed

# %%
co = repo.checkout(write=True, branch_name='master')

# %%
repo._details()
# Out:
# ======================
# Branch
# File Size: 32.77 kB
# ======================
#
# b'branch:add-test' b'3115bf8611987cc5e661e55bf994423b60683f9c'
# b'branch:add-validation' b'c2e49c3ef8eff20173f689af803c5d623d72c4fc'
# b'branch:conflictbranch' b'ec8691ca9b18cf8a730cbeb9a34157983c45e162'
# b'branch:master' b'5131376482d70f40c3d1519b09b9cb74fde01379'
# b'branch:untouched-live-demo-branch' b'395d988b638255ed75bd47e1d416fa75521e398e'
# b'head' b'branch:master'
# b'writerlock:' b'9f07acf7-9f4d-4ead-a60a-b6e96992c16e'
#
# ======================
# Label
# File Size: 28.67 kB
# ======================
#
# b'h:ace9b3802f7beb30d6cc569dea9a379102d5982e' b'bar'
# b'h:d8fa6800caf496e637d965faac1a033e4636c2e6' b'world'
# b'h:df4439ce38fccfb32d91537df433f3721ee596eb' b'world bar baz'
#
# ======================
# HASH
# File Size: 22.32 MB
# ======================
#
# b'h:0000b8a4c5c44ed62bd74f5f434ca73af2b20ad5' b'976ba57033bb 000 $ 77 346 * 784'
# b'a:test_images:1079' b'a1f2ff5363297d7373989b7b00954846754d452c'
# b'a:test_images:108' b'e84423af4995b05ab629963221d3e4abea070742'
# b'a:test_images:1080' b'cdaafff4b036445e627c539540e3571a8ea00e30'
# b'a:test_images:1081' b'878b2ef6a4069331c324f0dce341bb4c1f4b129d'
# b'a:test_images:1082' b'41edd7974f84b9ec1b85ae4b5bdef7bb5fe7cc21'
# b'a:test_images:1083' b'eb7896abf449cdb3b433fb497b5343082e0db875'
# b'a:test_images:1084' b'73c31819fee5d31f6ea40ac4509cf01a7f95af3b'
# b'a:test_images:1085' b'adb97046b5d3137cb719935aaa3f28b25b0f5bc0'

# %%
co.diff.branch('conflictbranch')
# Out:
# ({'metadata': {'master': {'additions': {'foo': 'ace9b3802f7beb30d6cc569dea9a379102d5982e'},
#     'removals': {},
#     'mutations': {},
#     'unchanged': {'hello': 'd8fa6800caf496e637d965faac1a033e4636c2e6'}},
#    'dev': {'additions': {'foo': 'df4439ce38fccfb32d91537df433f3721ee596eb'},
#     'removals': {},
#     'mutations': {},
#     'unchanged': {'hello': 'd8fa6800caf496e637d965faac1a033e4636c2e6'}}},
#   'datasets': {'master': {'additions': {'validation_images': RawDatasetSchemaVal(schema_uuid='ca33c0f47db611e98cc88c859047adef', schema_hash='976ba57033bb', schema_dtype=2, schema_is_var=False, schema_max_shape=(784,), schema_is_named=True),
#      'validation_labels': RawDatasetSchemaVal(schema_uuid='ca3418ba7db611e98cc88c859047adef', schema_hash='631f0f57c469', schema_dtype=7, schema_is_var=False, schema_max_shape=(1,), schema_is_named=True)},
#     'removals': {},
#     'mutations': {},
#     'unchanged': {'test_images': RawDatasetSchemaVal(schema_uuid='ce6a45307db611e98cc88c859047adef', schema_hash='976ba57033bb', schema_dtype=2, schema_is_var=False, schema_max_shape=(784,), schema_is_named=True),
#      'test_labels': RawDatasetSchemaVal(schema_uuid='d1614a907db611e98cc88c859047adef', schema_hash='631f0f57c469', schema_dtype=7, schema_is_var=False, schema_max_shape=(1,), schema_is_named=True),
#      'train_images': RawDatasetSchemaVal(schema_uuid='bf3e41927db611e98cc88c859047adef', schema_hash='976ba57033bb', schema_dtype=2, schema_is_var=False, schema_max_shape=(784,), schema_is_named=True),
#      'train_labels': RawDatasetSchemaVal(schema_uuid='bf433dfa7db611e98cc88c859047adef', schema_hash='631f0f57c469', schema_dtype=7, schema_is_var=False, schema_max_shape=(1,), schema_is_named=True)}},
#    'dev': {'additions': {},
#     'removals': {},
#     'mutations': {},
#     'unchanged': {'test_images': RawDatasetSchemaVal(schema_uuid='ce6a45307db611e98cc88c859047adef', schema_hash='976ba57033bb', schema_dtype=2, schema_is_var=False, schema_max_shape=(784,), schema_is_named=True),
#      'test_labels': RawDatasetSchemaVal(schema_uuid='d1614a907db611e98cc88c859047adef', schema_hash='631f0f57c469', schema_dtype=7, schema_is_var=False, schema_max_shape=(1,), schema_is_named=True),
#      'train_images': RawDatasetSchemaVal(schema_uuid='bf3e41927db611e98cc88c859047adef', schema_hash='976ba57033bb', schema_dtype=2, schema_is_var=False, schema_max_shape=(784,), schema_is_named=True),
): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='test_labels', data_name='8205'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='test_labels', data_name='9224'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='test_labels', data_name='3376'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='test_labels', data_name='7612'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='test_labels', data_name='1691'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='test_labels', data_name='4516'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
# ...
#       RawDataRecordKey(dset_name='train_labels', data_name='43412'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='3922'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='2508'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='47564'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='45941'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='47408'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='27452'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='16268'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='17016'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='44766'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='19121'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30153'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='14200'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='49545'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='28635'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4479'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='37020'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='21488'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='22580'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='26190'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='21881'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='48326'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='22950'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='35567'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4292'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4841'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='5499'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='49479'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='38158'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='41278'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='13323'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='40621'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='33183'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30665'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='28669'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='44222'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='28571'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='22697'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='12772'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='14389'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30492'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='24300'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='42090'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4927'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='14107'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='3545'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='32377'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='46477'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='479'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30767'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='2226'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30550'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='25386'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='12094'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4741'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='5272'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='3069'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='7835'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='26356'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='22910'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='12380'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='21105'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='17125'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='28624'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='41692'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='940'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='41732'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='21683'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='35378'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='6264'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='23360'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='38932'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='42385'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='41307'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='3965'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='18757'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='10710'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='13711'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='35677'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='20979'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='19234'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='3079'): RawDataRecordVal(data_hash='e2e0507d8c416d139b2a870750decef82f5fb4c2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='14815'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='16090'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='17498'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='37218'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='5915'): RawDataRecordVal(data_hash='fe9921394c99b45129ac41210fecc46e6277d1ca'),
#       RawDataRecordKey(dset_name='train_labels', data_name='15869'): RawDataRecordVal(data_hash='98a849b0216ea596aa6e7befc9516b9595562c38'),
#       RawDataRecordKey(dset_name='train_labels', data_name='36080'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='6348'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='25002'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='7257'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='7003'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='6529'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='14513'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='33087'): RawDataRecordVal(data_hash='3ce7ae2b17addc9bc18491b5756dcc52779153a1'),
#       RawDataRecordKey(dset_name='train_labels', data_name='4862'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='21826'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='24614'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='25043'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='32582'): RawDataRecordVal(data_hash='17bad2cbd97e353cc87ab0482a0aa3c35c8635d2'),
#       RawDataRecordKey(dset_name='train_labels', data_name='40025'): RawDataRecordVal(data_hash='a4b11adaf0899a29b686162d2e60fc4cc2625885'),
#       RawDataRecordKey(dset_name='train_labels', data_name='30562'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='47261'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='20753'): RawDataRecordVal(data_hash='3c3011cd6f611273cee85bc75286b9986e660df6'),
#       RawDataRecordKey(dset_name='train_labels', data_name='2851'): RawDataRecordVal(data_hash='799d2ea9815aa1f4cb0862890cce6dc65d5366bd'),
#       RawDataRecordKey(dset_name='train_labels', data_name='32623'): RawDataRecordVal(data_hash='33e043c67e5c800a8b5817a1a61403a3631f2a7e'),
#       RawDataRecordKey(dset_name='train_labels', data_name='31737'): RawDataRecordVal(data_hash='d8695fc4b68011a8ea2ecc2bd5663e6dc1a5212e'),
#       ...}}}}},
#  {'dset': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#   'meta': ConflictRecords(t1=('foo',), t21=(), t22=(), t3=(), conflict=True),
#   'sample': {'test_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#    'test_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#    'train_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#    'train_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#    'validation_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False),
#    'validation_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False)},
#   'conflict_found': True})

# %%
co.merge('error here', 'conflictbranch')
# Out:
# Selected 3-Way Merge Strategy
# HANGAR VALUE ERROR:: Merge ABORTED with conflict: {'dset': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'meta': ConflictRecords(t1=('foo',), t21=(), t22=(), t3=(), conflict=True), 'sample': {'test_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'test_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'train_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'train_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'validation_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'validation_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False)}, 'conflict_found': True}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2e0b176a062f> in <module>
# ----> 1 co.merge('error here', 'conflictbranch')
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/checkout.py in merge(self, message, dev_branch)
#     392             dev_branch_name=dev_branch,
#     393             repo_path=self._repo_path,
# --> 394             writer_uuid=self._writer_lock)
#     395
#     396         for dsetHandle in self._datasets.values():
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/merger.py in select_merge_algorithm(message, branchenv, stageenv, refenv, stagehashenv, master_branch_name, dev_branch_name, repo_path, writer_uuid)
#     125
#     126     except ValueError as e:
# --> 127         raise e
#     128
#     129     finally:
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/merger.py in select_merge_algorithm(message, branchenv, stageenv, refenv, stagehashenv, master_branch_name, dev_branch_name, repo_path, writer_uuid)
#     122                 refenv=refenv,
#     123                 stagehashenv=stagehashenv,
# --> 124                 repo_path=repo_path)
#     125
#     126     except ValueError as e:
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/merger.py in _three_way_merge(message, master_branch_name, masterHEAD, dev_branch_name, devHEAD, ancestorHEAD, branchenv, stageenv, refenv, stagehashenv, repo_path)
#     239     except ValueError as e:
#     240         logger.error(e, exc_info=False)
# --> 241         raise e from None
#     242
#     243     fmtCont = _merge_dict_to_lmdb_tuples(patchedRecs=mergeContents)
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/merger.py in _three_way_merge(message, master_branch_name, masterHEAD, dev_branch_name, devHEAD, ancestorHEAD, branchenv, stageenv, refenv, stagehashenv, repo_path)
#     236
#     237     try:
# --> 238         mergeContents = _compute_merge_results(a_cont=aCont, m_cont=mCont, d_cont=dCont)
#     239     except ValueError as e:
#     240         logger.error(e, exc_info=False)
#
# ~/projects/tensorwerk/hangar/hangar-py/src/hangar/merger.py in _compute_merge_results(a_cont, m_cont, d_cont)
#     333     if confs['conflict_found'] is True:
#     334         msg = f'HANGAR VALUE ERROR:: Merge ABORTED with conflict: {confs}'
# --> 335         raise ValueError(msg)
#     336
#     337     # merging: dataset schemas
#
# ValueError: HANGAR VALUE ERROR:: Merge ABORTED with conflict: {'dset': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'meta': ConflictRecords(t1=('foo',), t21=(), t22=(), t3=(), conflict=True), 'sample': {'test_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'test_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'train_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'train_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'validation_images': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False), 'validation_labels': ConflictRecords(t1=(), t21=(), t22=(), t3=(), conflict=False)}, 'conflict_found': True}

# %%
repo.log()
# Out:
# *   31d74893fb42562f26cdb23e818b436426589623 (master) : merge of removals with master
# |\
# | * 395d988b638255ed75bd47e1d416fa75521e398e (untouched-live-demo-branch) : removed index zero for train images and labels
# * |   3fd5d1fc99f08d901700c0c852a1575d7fc24df7 : adding in the new testing datasets
# |\ \
# | * | 3115bf8611987cc5e661e55bf994423b60683f9c (add-test) : added testing labels only
# | * | 7b7f24e64689bda604ae48280cae3877c334dfe1 : added testing images only
# | |/
# * | c2e49c3ef8eff20173f689af803c5d623d72c4fc (add-validation) : commit adding validation images and labels
# |/
# * cd5593d4a87953cfc928597334a1b664c45557f4 : first commit adding training images and labels

# %%
repo.summary()
# Out:
# Summary of Contents Contained in Data Repository
#
# ==================
# | Repository Info
# |-----------------
# |  Directory: /Users/rick/projects/tensorwerk/hangar/dev/mnist/__hangar
# |  Disk Usage: 83.19 MB
#
# ===================
# | Commit Details
# -------------------
# |  Commit: 31d74893fb42562f26cdb23e818b436426589623
# |  Created: Fri May 24 00:03:50 2019
# |  By: Rick Izzo
# |  Email: rick@tensorwerk.com
# |  Message: merge of removals with master
#
# ==================
# | DataSets
# |-----------------
# |  Number of Named Datasets: 6
# |
# |  * Dataset Name: test_images
# |    Num Arrays: 10000
# |    Details:
# |    - schema_uuid: ce6a45307db611e98cc88c859047adef
# |    - schema_hash: 976ba57033bb
# |    - schema_dtype: 2
# |    - schema_is_var: False
# |    - schema_max_shape: (784,)
# |    - schema_is_named: True
# |
# |  * Dataset Name: test_labels
# |    Num Arrays: 10000
# |    Details:
# |    - schema_uuid: d1614a907db611e98cc88c859047adef
# |    - schema_hash: 631f0f57c469
# |    - schema_dtype: 7
# |    - schema_is_var: False
# |    - schema_max_shape: (1,)
# |    - schema_is_named: True
# |
# |  * Dataset Name: train_images
# |    Num Arrays: 49999
# |    Details:
# |    - schema_uuid: bf3e41927db611e98cc88c859047adef
# |    - schema_hash: 976ba57033bb
# |    - schema_dtype: 2
# |    - schema_is_var: False
# |    - schema_max_shape: (784,)
# |    - schema_is_named: True
# |
# |  * Dataset Name: train_labels
# |    Num Arrays: 49999
# |    Details:
# |    - schema_uuid: bf433dfa7db611e98cc88c859047adef
# |    - schema_hash: 631f0f57c469
# |    - schema_dtype: 7
# |    - schema_is_var: False
# |    - schema_max_shape: (1,)
# |    - schema_is_named: True
# |
# |  * Dataset Name: validation_images
# |    Num Arrays: 10000
# |    Details:
# |    - schema_uuid: ca33c0f47db611e98cc88c859047adef
# |    - schema_hash: 976ba57033bb
# |    - schema_dtype: 2
# |    - schema_is_var: False
# |    - schema_max_shape: (784,)
# |    - schema_is_named: True
# |
# |  * Dataset Name: validation_labels
# |    Num Arrays: 10000
# |    Details:
# |    - schema_uuid: ca3418ba7db611e98cc88c859047adef
# |    - schema_hash: 631f0f57c469
# |    - schema_dtype: 7
# |    - schema_is_var: False
# |    - schema_max_shape: (1,)
# |    - schema_is_named: True
#
# ==================
# | Metadata:
# |-----------------
# |  Number of Keys: 1

# %%
rco = repo.checkout(branch_name='add-test')

# %%
rco.datasets

# %%
rco.metadata

# %%
co.close()
rco.close()

# %%
repo.log()
